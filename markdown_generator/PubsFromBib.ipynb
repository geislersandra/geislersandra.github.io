# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
# !pip install pybtex
# Out:
# Collecting pybtex
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      -------------------------------------- 561.4/561.4 KB 5.0 MB/s eta 0:00:00
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Collecting PyYAML>=3.01
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
#      -------------------------------------- 151.6/151.6 KB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\geisler\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pybtex) (1.16.0)
# Installing collected packages: PyYAML, latexcodec, pybtex
# Successfully installed PyYAML-6.0 latexcodec-2.0.1 pybtex-0.24.0
# WARNING: You are using pip version 22.0.4; however, version 23.1.1 is available.
# You should consider upgrading via the 'C:\Users\geisler\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "Own.bib",
        "venuekey": "booktitle",
        "venue-pretext": "In the proceedings of ",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    },
    "journal":{
        "file": "Own.bib",
        "venuekey" : "journal",
        "venue-pretext" : "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
    } 
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
# SUCESSFULLY PARSED Chakrabarti2018: " Goal-Oriented Modelling of Relations and Dependencies in Dat ... "
# SUCESSFULLY PARSED Deserno2017: " A presentation semantic for the operational data model  "
# SUCESSFULLY PARSED Geisler2017: " An Integrated Ontology-Based Approach for Patent Classificat ... "
# SUCESSFULLY PARSED Quix2017: " Ontology Matching for Patent Classification  "
# SUCESSFULLY PARSED Hai2016: " Constance: An intelligent data lake system  "
# WARNING Missing Expected Field 'booktitle' from entry Delot2016: " {Guest Editorial: Large-scale  ... "
# WARNING Missing Expected Field 'booktitle' from entry Geisler2016: " {Ontology-Based Data Quality M ... "
# SUCESSFULLY PARSED Quix2016: " {Recommender System f{\"u}r Projektkollaborationen basierend ... "
# SUCESSFULLY PARSED Geisler2015: " {An Ontology-based Collaboration Recommender System using Pa ... "
# WARNING Missing Expected Field 'booktitle' from entry Spreckelsen2015: " {Model-based approach for Opti ... "
# WARNING Missing Expected Field 'booktitle' from entry Schmeink2014: " {Method and Module for Creatin ... "
# WARNING Missing Expected Field 'booktitle' from entry Delot2014: " {Special Issue on Information  ... "
# SUCESSFULLY PARSED Geisler2013: " {Data Stream Management Systems}  "
# WARNING Missing Expected Field 'booktitle' from entry Schmidt2013: " {Decision Support for Hospital ... "
# SUCESSFULLY PARSED Quix2013: " {HealthNet: A System for Mobile and Wearable Health Informat ... "
# SUCESSFULLY PARSED Spreckelsen2013: " {Ontologiegest{\"u}tzte Parametrierung von Optimierungsalgor ... "
# WARNING Missing Expected Field 'author' from entry Delot2013: " {Proceedings of the 3rd Intern ... "
# WARNING Missing Expected Field 'booktitle' from entry Schmeink2020: " {A Method and Module for Linki ... "
# WARNING Missing Expected Field 'booktitle' from entry Geisler2012: " {An Evaluation Framework for T ... "
# SUCESSFULLY PARSED Geisler2012a: " {Evaluation of Real-time Traffic Applications based on Data  ... "
# SUCESSFULLY PARSED Rasim2011: " {A Universal Tool for Mobile Long-Time Recording, Monitoring ... "
# SUCESSFULLY PARSED Geisler2011: " {An Ontology-based Data Quality Framework for Data Stream Ap ... "
# SUCESSFULLY PARSED Li2011: " {Automatic Mediated Schema GeneratIon Through Reasoning over ... "
# WARNING Missing Expected Field 'booktitle' from entry Fiege2011: " {ITS Services and Communicatio ... "
# SUCESSFULLY PARSED Geisler2010: " {A Data Stream-based Evaluation Framework for Traffic Inform ... "
# SUCESSFULLY PARSED Geisler2010a: " {Accuracy Assessment for Traffic Information Derived from Fl ... "
# SUCESSFULLY PARSED Li2010: " {Automatic schema merging using mapping constraints among in ... "
# SUCESSFULLY PARSED Geisler2010b: " {Ontology-based Data Integration: A Case Study in Clinical T ... "
# SUCESSFULLY PARSED Kensche2010: " {Solving ORM by MAGIC: MApping GeneratIon and Composition}  "
# SUCESSFULLY PARSED Geisler2009: " {A Quality- and Priority-based Traffic Information Fusion Ar ... "
# SUCESSFULLY PARSED Soboll2009: " {Prozessmodellierung der mobilen Datenerfassung f{\"u}r den  ... "
# SUCESSFULLY PARSED Quix2009: " {Results of GeRoMeSuite for OAEI 2009}  "
# SUCESSFULLY PARSED Quix2009a: " {View Management Techniques and Their Application to Data St ... "
# SUCESSFULLY PARSED Wessel2008: " {Efficient Quality Assurance in Process Models - An Example: ... "
# SUCESSFULLY PARSED Wessel2008a: " {Software-Engineering in Multidisciplinary Teams in Health I ... "
# SUCESSFULLY PARSED Geisler2007: " {An Ontology-Based System for Clinical Trial Data Management ... "
# SUCESSFULLY PARSED Soboll2007: " {Exploration and Requirement Analysis for Mobile Data Commun ... "
# WARNING Missing Expected Field 'booktitle' from entry Frerich2021: " {On the Potential of Taxonomic ... "
# SUCESSFULLY PARSED Bader2020: " The International Data Spaces Information Model -- An Ontolo ... "
# WARNING Missing Expected Field 'booktitle' from entry Bukowski2020: " Feasibility of activity-based  ... "
# SUCESSFULLY PARSED Geisler2020: " {Database Management Systems (DBMS)}  "
# SUCESSFULLY PARSED Quix2020: " {Data Lake}  "
# SUCESSFULLY PARSED Geisler2020a: " {Complex Event Processing}  "
# SUCESSFULLY PARSED Geisler2020b: " {Use Cases from the Medical Domain}  "
# WARNING Missing Expected Field 'booktitle' from entry Geisler2021: " {Knowledge-driven Data Ecosyst ... "
# WARNING Missing Expected Field 'journal' from entry Chakrabarti2018: " Goal-Oriented Modelling of Rel ... "
# WARNING Missing Expected Field 'journal' from entry Deserno2017: " A presentation semantic for th ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2017: " An Integrated Ontology-Based A ... "
# WARNING Missing Expected Field 'journal' from entry Quix2017: " Ontology Matching for Patent C ... "
# WARNING Missing Expected Field 'journal' from entry Hai2016: " Constance: An intelligent data ... "
# SUCESSFULLY PARSED Delot2016: " {Guest Editorial: Large-scale Data Management for Mobile App ... "
# SUCESSFULLY PARSED Geisler2016: " {Ontology-Based Data Quality Management for Data Streams}  "
# WARNING Missing Expected Field 'journal' from entry Quix2016: " {Recommender System f{\"u}r Pr ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2015: " {An Ontology-based Collaborati ... "
# SUCESSFULLY PARSED Spreckelsen2015: " {Model-based approach for Optimizing the Storage Management  ... "
# WARNING Missing Expected Field 'journal' from entry Schmeink2014: " {Method and Module for Creatin ... "
# SUCESSFULLY PARSED Delot2014: " {Special Issue on Information Management in Mobile Applicati ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2013: " {Data Stream Management System ... "
# SUCESSFULLY PARSED Schmidt2013: " {Decision Support for Hospital Bed Management Using Adaptabl ... "
# WARNING Missing Expected Field 'journal' from entry Quix2013: " {HealthNet: A System for Mobil ... "
# WARNING Missing Expected Field 'journal' from entry Spreckelsen2013: " {Ontologiegest{\"u}tzte Parame ... "
# WARNING Missing Expected Field 'author' from entry Delot2013: " {Proceedings of the 3rd Intern ... "
# WARNING Missing Expected Field 'journal' from entry Schmeink2020: " {A Method and Module for Linki ... "
# SUCESSFULLY PARSED Geisler2012: " {An Evaluation Framework for Traffic Information Systems Bas ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2012a: " {Evaluation of Real-time Traff ... "
# WARNING Missing Expected Field 'journal' from entry Rasim2011: " {A Universal Tool for Mobile L ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2011: " {An Ontology-based Data Qualit ... "
# WARNING Missing Expected Field 'journal' from entry Li2011: " {Automatic Mediated Schema Gen ... "
# WARNING Missing Expected Field 'journal' from entry Fiege2011: " {ITS Services and Communicatio ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2010: " {A Data Stream-based Evaluatio ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2010a: " {Accuracy Assessment for Traff ... "
# WARNING Missing Expected Field 'journal' from entry Li2010: " {Automatic schema merging usin ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2010b: " {Ontology-based Data Integrati ... "
# WARNING Missing Expected Field 'journal' from entry Kensche2010: " {Solving ORM by MAGIC: MApping ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2009: " {A Quality- and Priority-based ... "
# WARNING Missing Expected Field 'journal' from entry Soboll2009: " {Prozessmodellierung der mobil ... "
# WARNING Missing Expected Field 'journal' from entry Quix2009: " {Results of GeRoMeSuite for OA ... "
# WARNING Missing Expected Field 'journal' from entry Quix2009a: " {View Management Techniques an ... "
# WARNING Missing Expected Field 'journal' from entry Wessel2008: " {Efficient Quality Assurance i ... "
# WARNING Missing Expected Field 'journal' from entry Wessel2008a: " {Software-Engineering in Multi ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2007: " {An Ontology-Based System for  ... "
# WARNING Missing Expected Field 'journal' from entry Soboll2007: " {Exploration and Requirement A ... "
# SUCESSFULLY PARSED Frerich2021: " {On the Potential of Taxonomic Graphs to Improve Applicabili ... "
# WARNING Missing Expected Field 'journal' from entry Bader2020: " The International Data Spaces  ... "
# SUCESSFULLY PARSED Bukowski2020: " Feasibility of activity-based expert profiling using text mi ... "
# WARNING Missing Expected Field 'journal' from entry Geisler2020: " {Database Management Systems ( ... "
# WARNING Missing Expected Field 'journal' from entry Quix2020: " {Data Lake}  "
# WARNING Missing Expected Field 'journal' from entry Geisler2020a: " {Complex Event Processing}  "
# WARNING Missing Expected Field 'journal' from entry Geisler2020b: " {Use Cases from the Medical Do ... "
# SUCESSFULLY PARSED Geisler2021: " {Knowledge-driven Data Ecosystems Towards Data Transparency}  "
